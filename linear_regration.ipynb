# %% [markdown]
# <a href="https://colab.research.google.com/github/sam2005-max/my_linear_regression/blob/main/linear_regration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U scikit-learn

# %%
import numpy as np
import matplotlib as plt
from sklearn.metrics import mean_squared_error

# %%
def h(x,theta):
    return [[i] for i in np.dot(x, theta)]

# %%
def mean_squared_error(y_predicted, y_label):
    mse = np.square(np.subtract(y_label,y_predicted)).mean()
    return mse

# %%
class LeastSquaresRegression():
    import matplotlib.pyplot as plt

    
    
    def __init__(self):
        
        self.theta_ = None 

    def fit(self, X, y):
        # X = 4 * np.random.rand(100, 1)
        # y = 10 + 2 * X + np.random.randn(100, 1)
        self.theta_ = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

      
        # self = w
 # Return the classifier
        # return w

    def predict(self, X):
        # y_pred = np.dot(X, w[0])
        return h(X, self.theta_)
        # return self.y_pred[closest]

# %%
import numpy as np
import matplotlib.pyplot as plt

X = 4 * np.random.rand(100, 1)
y = 10 + 2 * X + np.random.randn(100, 1)
def bias_column(X):
    # X = 4 * np.random.rand(100, 1)
    return np.hstack((np.ones((np.size(X, 0), 1)),X))

    
#X_new = eg.bias_column(X)
X_new = bias_column(X)

print(X[:5])
print(" ---- ")
# Out:
# [[3.58075856]
#  [0.46563148]
#  [3.55174208]
#  [0.01866354]
#  [1.91792398]]
#  ----

# %%
model = LeastSquaresRegression()
model.fit(X_new, y)
print(model.theta_)

y_new = model.predict(X_new)

def my_plot(X, y, y_new):
    plt.scatter(X,y)
    # plt.plot(X_new,y_new, color = 'k')
    plt.show()
     

my_plot(X, y, y_new)
# Out:
# [[10.10809712]
#  [ 1.92050259]]

# %%
class GradientDescentOptimizer():

    def __init__(self, f, fprime, start, learning_rate = 0.1):
        self.f_      = f                       # The function
        self.fprime_ = fprime                  # The gradient of f
        self.current_ = start                  # The current point being evaluated
        self.learning_rate_ = learning_rate    # Does this need a comment ?

        # Save history as attributes
        self.history_ = [start]
    
    def step(self):
        for _ in range(100):
            self.current_ = start - learning_rate * fprime(start)
            self.history_ = self.history_.add(self.current_)
        # Take a gradient descent step
        # 1. Compute the new value and update self.current_
        # 2. Append the new value to history
        # Does not return anything

        
        
    def optimize(self, iterations = 100):
        for i in range(iterations):
            return i
            
        # Use the gradient descent to get closer to the minimum:
        # For each iteration, take a gradient step

    def getCurrentValue(self):
        return  [0.2 for x in self.current_]
                            
      # Getter for current_

    def print_result(self):
        print("Best theta found is " + str(self.current_))
        print("Value of f at this theta: f(theta) = " + str(self.f_(self.current_)))
        print("Value of f prime at this theta: f'(theta) = " + str(self.fprime_(self.current_)))
        return self.history_

# %%
def f(x):
    return 3 + np.dot((np.squeeze(np.asarray(x)) - np.array([[2], [6]]).T).T, np.squeeze(np.asarray(x)) - np.array([[2], [6]]).T)
def fprime(x):
    return 2 * (x - np.array([[2], [6]]))


grad = GradientDescentOptimizer(f, fprime, np.random.normal(size=(2,)), 0.1)
grad.optimize(10)
grad.print_result()
# Out:
# Best theta found is [-1.05530341 -0.00597377]
# Value of f at this theta: f(theta) = [[12.33487891 21.35007213]
#  [21.35007213 39.07172095]]
# Value of f prime at this theta: f'(theta) = [[ -6.11060681  -4.01194754]
#  [-14.11060681 -12.01194754]]
# [array([-1.05530341, -0.00597377])]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')   # Create the axes

# Data
X = np.linspace(-8, 8, 100)
Y = np.linspace(-4, 4, 100)
X, Y = np.meshgrid(X, Y)
Z = X**2 + Y**2

# Plot the 3d surface
surface = ax.plot_surface(X, Y, Z,
                          cmap=cm.coolwarm,
                          rstride = 2,
                          cstride = 2)

# Set some labels
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')

plt.show()
